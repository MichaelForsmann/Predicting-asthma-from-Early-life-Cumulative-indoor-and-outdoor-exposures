# %%
import pandas as pd
import arviz as az
from Functions import *

# %%
data=pd.read_excel(r"../Data_and_Preprocessing/before_season_correction.xlsx")

# %%
train=data.loc[data.label==0,:]

# %%
device="cuda"

# %%
train_no2=train.dropna(subset="no2")
X_no2,y_no2=torch.tensor(train_no2.corrected_week.values).to(device),torch.tensor(train_no2.no2.values).to(device)
nuts_kernel,gpr_no2=model(X_no2,y_no2,device) 
pyro_data_no2,gpr_no2=train_model(X_no2,nuts_kernel,gpr_no2,device) 
az.to_json(pyro_data_no2, "Arviz_stats/mcmc_no2_seasonality.json")
torch.save(gpr_no2,"models/no2_seasonality");
# Out:
# /home/michaelf/Pyro_periodic/Seasonality_functions/Functions.py:25: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   rbf.period=torch.tensor(X.max())
# Sample: 100%|██████████████████████████████████████| 10500/10500 [05:05, 34.40it/s, step size=7.22e-01, acc. prob=0.934]
# /data/michaelf/miniconda3/lib/python3.10/site-packages/arviz/data/io_pyro.py:158: UserWarning: Could not get vectorized trace, log_likelihood group will be omitted. Check your model vectorization or set log_likelihood=False
#   warnings.warn(

# %%
train_nox=train.dropna(subset="nox")
X_nox,y_nox=torch.tensor(train_nox.corrected_week.values).to(device),torch.tensor(train_nox.nox.values).to(device)
nuts_kernel,gpr_nox=model(X_nox,y_nox,device) 
pyro_data_nox,gpr_nox=train_model(X_nox,nuts_kernel,gpr_nox,device) 
az.to_json(pyro_data_nox, "Arviz_stats/mcmc_nox_seasonality.json")
torch.save(gpr_nox,"models/nox_seasonality");
# Out:
# /home/michaelf/Pyro_periodic/Seasonality_functions/Functions.py:25: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   rbf.period=torch.tensor(X.max())
# Sample: 100%|██████████████████████████████████████| 10500/10500 [05:53, 29.74it/s, step size=7.57e-01, acc. prob=0.919]
# /data/michaelf/miniconda3/lib/python3.10/site-packages/arviz/data/io_pyro.py:158: UserWarning: Could not get vectorized trace, log_likelihood group will be omitted. Check your model vectorization or set log_likelihood=False
#   warnings.warn(
