# %%
import arviz as az

# %%
pyro_data_acetald=az.from_json("models/mcmc_acetald_seasonality.json")
pyro_data_acetone=az.from_json("models/mcmc_acetone_seasonality.json")
pyro_data_form=az.from_json("models/mcmc_form_seasonality.json")
pyro_data_no2=az.from_json("models/mcmc_no2_seasonality.json")
pyro_data_nox=az.from_json("models/mcmc_nox_seasonality.json")
pyro_data_pm25=az.from_json("models/mcmc_PM25_seasonality.json")
pyro_data_bc=az.from_json("models/mcmc_BC_seasonality.json")
pyro_data_voc=az.from_json("models/mcmc_vocs_seasonality.json")

# %%
az.summary(pyro_data_acetald)
# Out:
#                       mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# kernel.lengthscale   2.266  0.683   1.081    3.556      0.008    0.008
# kernel.variance     14.348  4.128   7.235   22.110      0.046    0.044
# noise               39.647  2.121  35.664   43.620      0.025    0.024
#
#                     ess_bulk  ess_tail  r_hat
# kernel.lengthscale    7101.0    5883.0    1.0
# kernel.variance       7744.0    5790.0    1.0
# noise                 7440.0    5726.0    1.0

# %%
az.summary(pyro_data_pm25)
# Out:
#                        mean      sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# kernel.lengthscale    2.533   0.737    1.295    3.907      0.009    0.009
# kernel.variance      47.709  10.883   28.224   68.046      0.121    0.113
# noise               245.541   8.255  229.977  260.733      0.089    0.088
#
#                     ess_bulk  ess_tail  r_hat
# kernel.lengthscale    7549.0    6123.0    1.0
# kernel.variance       7840.0    5663.0    1.0
# noise                 8513.0    5923.0    1.0

# %%
az.summary(pyro_data_bc)
# Out:
#                      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# kernel.lengthscale  1.987  0.912   0.721    3.838      0.014    0.014
# kernel.variance     0.859  0.470   0.194    1.750      0.006    0.006
# noise               0.265  0.013   0.241    0.291      0.000    0.000
#
#                     ess_bulk  ess_tail  r_hat
# kernel.lengthscale    4991.0    5445.0    1.0
# kernel.variance       5895.0    5987.0    1.0
# noise                 5979.0    5355.0    1.0

# %%
az.summary(pyro_data_form)
# Out:
#                        mean      sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# kernel.lengthscale    3.114   1.142    1.243    5.236      0.013    0.014
# kernel.variance      46.240  11.629   25.701   67.937      0.137    0.125
# noise               219.120   8.265  204.472  235.438      0.095    0.091
#
#                     ess_bulk  ess_tail  r_hat
# kernel.lengthscale    7057.0    5356.0    1.0
# kernel.variance       6956.0    5198.0    1.0
# noise                 7518.0    6255.0    1.0

# %%
az.summary(pyro_data_no2)
# Out:
#                       mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# kernel.lengthscale   3.605  1.147   1.668    5.721      0.013    0.012
# kernel.variance     15.513  4.973   7.081   24.916      0.057    0.055
# noise               23.637  1.260  21.090   25.828      0.014    0.013
#
#                     ess_bulk  ess_tail  r_hat
# kernel.lengthscale    7017.0    5363.0    1.0
# kernel.variance       7374.0    5644.0    1.0
# noise                 8379.0    6166.0    1.0

# %%
az.summary(pyro_data_nox)
# Out:
#                        mean     sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# kernel.lengthscale    1.142  0.220    0.742    1.560      0.003    0.003
# kernel.variance      50.317  9.399   33.314   68.081      0.107    0.101
# noise               251.950  9.770  234.212  270.261      0.111    0.102
#
#                     ess_bulk  ess_tail  r_hat
# kernel.lengthscale    7479.0    5707.0    1.0
# kernel.variance       7609.0    5818.0    1.0
# noise                 7819.0    5806.0    1.0

# %%
az.summary(pyro_data_pm25)
# Out:
#                        mean      sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# kernel.lengthscale    2.533   0.737    1.295    3.907      0.009    0.009
# kernel.variance      47.709  10.883   28.224   68.046      0.121    0.113
# noise               245.541   8.255  229.977  260.733      0.089    0.088
#
#                     ess_bulk  ess_tail  r_hat
# kernel.lengthscale    7549.0    6123.0    1.0
# kernel.variance       7840.0    5663.0    1.0
# noise                 8513.0    5923.0    1.0

# %%
az.summary(pyro_data_bc)
# Out:
#                      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# kernel.lengthscale  1.987  0.912   0.721    3.838      0.014    0.014
# kernel.variance     0.859  0.470   0.194    1.750      0.006    0.006
# noise               0.265  0.013   0.241    0.291      0.000    0.000
#
#                     ess_bulk  ess_tail  r_hat
# kernel.lengthscale    4991.0    5445.0    1.0
# kernel.variance       5895.0    5987.0    1.0
# noise                 5979.0    5355.0    1.0

# %%
az.summary(pyro_data_voc)
# Out:
#                        mean      sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# kernel.lengthscale    2.818   0.762    1.565    4.300      0.009    0.010
# kernel.variance     103.549  20.393   68.431  143.517      0.225    0.227
# noise               419.033  13.561  392.694  443.783      0.151    0.142
#
#                     ess_bulk  ess_tail  r_hat
# kernel.lengthscale    7681.0    5904.0    1.0
# kernel.variance       8166.0    6016.0    1.0
# noise                 8093.0    5907.0    1.0

# %%
az.plot_trace(pyro_data_voc)
# Out:
# array([[<Axes: title={'center': 'kernel.lengthscale'}>,
#         <Axes: title={'center': 'kernel.lengthscale'}>],
#        [<Axes: title={'center': 'kernel.variance'}>,
#         <Axes: title={'center': 'kernel.variance'}>],
#        [<Axes: title={'center': 'noise'}>,
#         <Axes: title={'center': 'noise'}>]], dtype=object)
