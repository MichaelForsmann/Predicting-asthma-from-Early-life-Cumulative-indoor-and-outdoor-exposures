# %%
from Scripts.Random_forest_nested import *

# %%
df = pd.read_excel('Data/Clinical_synthetic.xlsx', index_col=0)
X,y=df.drop(['constrution_year', 'Area', 'floor_level', 'powerplant',
       'road', 'motorway', 'forest', 'coastline', 'airport', 'farmland',
       'industrial', 'carpet', 'cookerhood', 'passive', 'gastove', 'fireplace',
       'corrected_week','scale_formaldehyd', 'scale_acetald', 'scale_vocs',"scaled_vocs",
      'asthma_0_7yrs', 'verificeret_18y', 'verificeret_12y', 'crp_6mo', 'il_1β_6mo', 'il_8_6mo', 'il_6_6mo',
       'tnf_α_6mo', 'urti_1y', 'rti_1y', 'fever_1y', 'gi_1y',
       'any_1y', 'lrti_3yr', 'urti_3yr', 'rti_3yr', 'fever_3yr', 'gi_3yr',
       'any_3yr'],axis=1),df.verificeret_18y
NUM_TRIALS=2

# %%
list_parameters=["Indoor Acetald","Indoor Acetone","Indoor formaldehyd","Indoor $PM_{2.5}$","Indoor $NO_x$","Indoor black Carbon","Indoor $NO_2$","passive","Lower respiratory tract infection","Genetics","gestational_age","mother","BMI","Outdoor $NO_2$","Outdoor $NO_x$","Outdoor $PM_{2.5}$",'Regeion $NO_x$','Region $NO_2 $'
,'Region $PM_{2.5}$',"landeuse1","landuse2"]

# %%
replace_dict=dict(zip(X.columns,list_parameters))
X=X.rename(columns=replace_dict)

# %%
X.columns
# Out:
# Index(['Indoor Acetald', 'Indoor Acetone', 'Indoor formaldehyd',
#        'Indoor $PM_{2.5}$', 'Indoor $NO_x$', 'Indoor black Carbon',
#        'Indoor $NO_2$', 'passive', 'Lower respiratory tract infection',
#        'Genetics', 'gestational_age', 'mother', 'BMI', 'Outdoor $NO_2$',
#        'Outdoor $NO_x$', 'Outdoor $PM_{2.5}$', 'Regeion $NO_x$',
#        'Region $NO_2 $', 'Region $PM_{2.5}$', 'landeuse1'],
#       dtype='object')

# %%
param_distributions = {
    'n_estimators': randint(100, 400),
    'max_depth': randint(2, 6),"min_impurity_decrease":uniform(0, 0.1),"min_samples_leaf":randint(20, 50)
,"class_weight":['balanced'],"max_features":[0.4,0.5,0.6],"max_samples":[0.4,0.5,0.6],"criterion":[ 'gini']}
performence,shap_values,feature_importance,parameter=nested_cross_validation_classification(X,y,2,3,param_distributions)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# done % 0.16666666666666666
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# done % 0.3333333333333333
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# done % 0.5
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# done % 0.6666666666666666
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# done % 0.8333333333333334
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# done % 1.0

# %%
shap_y12=dict(zip(X.columns,X.columns+"_12y"))
shapy12=pd.DataFrame(shap_values[:,:,1],columns=shap_y12)
shapy12.to_excel("shap12.xlsx")

# %%
performence.to_excel("Models/performence_rf_adjusted_18.xlsx")

# %%
performence.AUROC_train.mean(),performence.AUROC_train.std(),performence.AUROC_test.mean(),performence.AUROC_test.std()
# Out:
# (0.7753070212171972,
#  0.04349587677798432,
#  0.5555129068462402,
#  0.06426570262969329)

# %%
performence.F1_train.mean(),performence.F1_train.std(),performence.F1_test.mean(),performence.F1_test.std()
# Out:
# (0.5164859333887374,
#  0.05631893759871493,
#  0.3251687935840701,
#  0.03451586785769083)

# %%
feature_importance
# Out:
# Indoor Acetald                       0.079543
# Indoor Acetone                       0.043724
# Indoor formaldehyd                   0.047840
# Indoor $PM_{2.5}$                    0.030291
# Indoor $NO_x$                        0.034415
# Indoor black Carbon                  0.046399
# Indoor $NO_2$                        0.050499
# passive                              0.079028
# Lower respiratory tract infection    0.050527
# Genetics                             0.073682
# gestational_age                      0.071595
# mother                               0.020988
# BMI                                  0.048571
# Outdoor $NO_2$                       0.057452
# Outdoor $NO_x$                       0.028949
# Outdoor $PM_{2.5}$                   0.023047
# Regeion $NO_x$                       0.001696
# Region $NO_2 $                       0.087806
# Region $PM_{2.5}$                    0.021874
# landeuse1                            0.102073
# dtype: float64

# %%
fig=shap.plots.violin(shap_values[:,:,1],X ,plot_type="layered_violin")
# Out:
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #1 for feature Regeion $NO_x$, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #4 for feature Regeion $NO_x$, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #5 for feature Regeion $NO_x$, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #6 for feature Regeion $NO_x$, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #7 for feature Regeion $NO_x$, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #8 for feature Regeion $NO_x$, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #10 for feature Regeion $NO_x$, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
