# %%
from Scripts.Random_forest_nested import *

# %%
df = pd.read_excel('Data/Clinical_synthetic.xlsx', index_col=0)
X,y=df.drop(['constrution_year', 'Area', 'floor_level', 'powerplant',
       'road', 'motorway', 'forest', 'coastline', 'airport', 'farmland',
       'industrial', 'carpet', 'cookerhood', 'passive', 'gastove', 'fireplace',
       'corrected_week','scale_formaldehyd', 'scale_acetald', 'scale_vocs',"scaled_vocs",
      'asthma_0_7yrs', 'verificeret_18y', 'verificeret_12y', 'crp_6mo', 'il_1β_6mo', 'il_8_6mo', 'il_6_6mo',
       'tnf_α_6mo', 'urti_1y', 'rti_1y', 'fever_1y', 'gi_1y',
       'any_1y', 'lrti_3yr', 'urti_3yr', 'rti_3yr', 'fever_3yr', 'gi_3yr',
       'any_3yr'],axis=1),df.asthma_0_7yrs
NUM_TRIALS=2

# %%
list_parameters=["Indoor Acetald","Indoor Acetone","Indoor formaldehyd","Indoor $PM_{2.5}$","Indoor $NO_x$","Indoor black Carbon","Indoor $NO_2$","passive","Genetics","gestational_age","mother","BMI","Street $NO_2$","Street $NO_x$","Street $PM_{2.5}$",'Region $NO_x$','Region $NO_2 $'
,'Region $PM_{2.5}$',"landeuse1","landuse2"]

# %%
df
# Out:
#      acetald_season_m18  acetone_season_m18  form_season_m18  pm25_season_m18  \
# 1              0.158000            1.266562        -0.326627        -0.719408
# 3             -0.207010           -0.272260        -0.143481         3.098117
# 4             -0.144120           -0.368127         0.165602        -0.036140
# 5              0.155130            0.172504        -0.368279        -0.538218
# 7              0.536839            1.076798         2.958837         1.365320
# ..                  ...                 ...              ...              ...
# 449           -0.819100           -0.848213         0.057965        -0.052745
# 450           -1.227496           -1.005646         0.436408         0.000282
# 451           -0.202853           -0.150232        -0.124432         0.586525
# 452            0.681869            0.052266        -0.672787         0.036148
# 453           -0.179671           -0.167290        -0.048822         0.009776
#
#      nox_season_m18  bc_season_m18  no2_season_m18  passive_m18   lrti_1y  \
# 1         -0.372627      -0.556513       -0.189845     0.785007 -0.468348
# 3         10.329990       0.201867        5.122227     1.487370 -0.468348
# 4         -0.065395      -0.073302       -0.275286    -0.254995 -0.468348
# 5          0.027910      -0.567530        0.097914    -0.737752 -0.468348
# 7          0.511911       0.110948       -0.516821     0.785007 -0.468348
# ..              ...            ...             ...          ...       ...
# 449       -0.479954       0.011479       -0.650245    -0.737752 -0.468348
# 450       -0.559879      -0.037215       -0.801885     2.307766 -0.468348
# 451       -0.129946       2.318864        0.248254    -0.737752  1.042960
# 452        0.378740       1.269074        0.763894    -0.377583 -0.468348
# 453        0.109845       0.056440        0.480387     0.174550  1.042960
#
#      genetic_risk_score_asthma  ...  nox_str_m18  pm25_str_m18  nox_urb_m18  \
# 1                     0.089911  ...    -0.842286     -0.445187    -1.622824
# 3                    -1.092242  ...     0.268760      0.280107     1.062967
# 4                     1.632720  ...    -0.323772     -0.248535     0.173929
# 5                    -0.310819  ...    -0.639158     -0.409966    -0.918943
# 7                    -1.402807  ...    -0.216034     -0.071898     0.547261
# ..                         ...  ...          ...           ...          ...
# 449                   1.432355  ...    -0.442046      0.252210    -0.235913
# 450                   0.310312  ...    -0.386357      0.682245    -0.042941
# 451                   0.200112  ...     0.209366      1.299316    -0.272930
# 452                  -0.040326  ...    -0.266076      0.775398     0.373856
# 453                  -0.891877  ...     2.015059      2.094460    -0.726219
#
#      no2_urb_m18  pm25_urb_m18          PCA1          PCA2  asthma_0_7yrs  \
# 1      -1.673047     -0.276415 -1.039862e+00 -8.816905e-01              0
# 3       0.958328      0.401277  3.557848e+00 -1.313086e+00              0
# 4       0.026843      0.018664  9.820784e-18  6.108183e-19              0
# 5      -0.870882     -0.223565 -2.717014e+00 -4.109284e-01              1
# 7       0.484601      0.283711 -8.816375e-01 -5.598576e-01              0
# ..           ...           ...           ...           ...            ...
# 449    -0.177081      0.770041 -3.487012e-01  1.114797e+00              1
# 450     0.047284      1.415315  7.856915e-01  1.217329e+00              0
# 451    -0.254823      1.688677 -3.494975e-02  3.061230e-01              0
# 452     0.514732      1.555093  2.125883e+00  9.878339e-01              0
# 453    -0.765771      0.913166  9.820784e-18  6.108183e-19              0
#
#      verificeret_12y  verificeret_18y
# 1                  0                1
# 3                  0                0
# 4                  1                1
# 5                  1                1
# 7                  0                0
# ..               ...              ...
# 449                0                0
# 450                0                0
# 451                0                0
# 452                0                0
# 453                0                0
#
# [411 rows x 24 columns]

# %%
replace_dict=dict(zip(X.columns,list_parameters))
X=X.rename(columns=replace_dict)

# %%
replace_dict
# Out:
# {'acetald_season_m18': 'Indoor Acetald',
#  'acetone_season_m18': 'Indoor Acetone',
#  'form_season_m18': 'Indoor formaldehyd',
#  'pm25_season_m18': 'Indoor $PM_{2.5}$',
#  'nox_season_m18': 'Indoor $NO_x$',
#  'bc_season_m18': 'Indoor black Carbon',
#  'no2_season_m18': 'Indoor $NO_2$',
#  'passive_m18': 'passive',
#  'genetic_risk_score_asthma': 'Genetics',
#  'gestational_age': 'gestational_age',
#  "mother's_education_1yr": 'mother',
#  'bmi_6_yrs': 'BMI',
#  'no2_str_m18': 'Street $NO_2$',
#  'nox_str_m18': 'Street $NO_x$',
#  'pm25_str_m18': 'Street $PM_{2.5}$',
#  'nox_urb_m18': 'Region $NO_x$',
#  'no2_urb_m18': 'Region $NO_2 $',
#  'pm25_urb_m18': 'Region $PM_{2.5}$',
#  'PCA1': 'landeuse1',
#  'PCA2': 'landuse2'}

# %%
param_distributions = {
    'n_estimators': randint(100, 400),
    'max_depth': randint(2, 6),"min_impurity_decrease":uniform(0, 0.1),"min_samples_leaf":randint(20, 50)
,"class_weight":['balanced'],"max_features":[0.4,0.5,0.6],"max_samples":[0.4,0.5,0.6],"criterion":[ 'gini']}
performence,shap_values,feature_importance,parameter=nested_cross_validation_classification(X,y,2,3,param_distributions)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# done % 0.16666666666666666
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# done % 0.3333333333333333
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# done % 0.5
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# done % 0.6666666666666666
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# done % 0.8333333333333334
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# done % 1.0

# %%
shap_y12=dict(zip(X.columns,X.columns+"_12y"))
shapy12=pd.DataFrame(shap_values[:,:,1],columns=shap_y12)
shapy12.to_excel("shap12.xlsx")

# %%
performence.AUROC_train.mean(),performence.AUROC_train.std(),performence.AUROC_test.mean(),performence.AUROC_test.std()
# Out:
# (0.8362872682494262,
#  0.015498514993832792,
#  0.5895327942497754,
#  0.04038206473734885)

# %%
performence.to_excel("Models/performence_rf_7_adjusted.xlsx")

# %%
performence.F1_train.mean(),performence.F1_train.std(),performence.F1_test.mean(),performence.F1_test.std()
# Out:
# (0.5448635192652568,
#  0.017686025588851045,
#  0.29014878840965797,
#  0.06339132379492146)

# %%
feature_importance
# Out:
# scaled_nox                   0.025575
# scaled_no2                   0.047818
# scaled_formaldehyd           0.049755
# scaled_acetone               0.040705
# scaled_acetald               0.028148
# scaled_bc                    0.036635
# scaled_PM25                  0.033946
# no2_regional                 0.021607
# nox_regional                 0.028231
# pm25_regional                0.028272
# no2_street                   0.034835
# nox_street                   0.043129
# pm25_street                  0.035805
# bmi_6_yrs                    0.114531
# gestational_age              0.022193
# mother's_education_1yr       0.019829
# lrti_1y                      0.040024
# genetic_risk_score_asthma    0.191050
# PCA1                         0.026634
# PCA2                         0.131278
# dtype: float64

# %%
fig=shap.plots.violin(shap_values[:,:,1],X ,plot_type="layered_violin")
# Out:
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #1 for feature lrti_1y, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #4 for feature lrti_1y, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #5 for feature lrti_1y, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #6 for feature lrti_1y, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #7 for feature lrti_1y, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #8 for feature lrti_1y, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #10 for feature lrti_1y, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
