# %%
from Scripts.Random_forest_nested import *

# %%
df = pd.read_excel('Data/Clinical_synthetic.xlsx', index_col=0)
X,y=df.drop(['constrution_year', 'Area', 'floor_level', 'powerplant',
       'road', 'motorway', 'forest', 'coastline', 'airport', 'farmland',
       'industrial', 'carpet', 'cookerhood', 'passive', 'gastove', 'fireplace',
       'corrected_week','scale_formaldehyd', 'scale_acetald', 'scale_vocs',"scaled_vocs",'bmi_6_yrs', 'mother\'s_education_1yr',
       'PCA1', 'PCA2','asthma_0_7yrs', 'verificeret_18y', 'verificeret_12y', 'crp_6mo', 'il_1β_6mo', 'il_8_6mo', 'il_6_6mo',
       'tnf_α_6mo', 'urti_1y', 'rti_1y', 'fever_1y', 'gi_1y',
       'any_1y', 'lrti_3yr', 'urti_3yr', 'rti_3yr', 'fever_3yr', 'gi_3yr',
       'any_3yr'],axis=1),df.verificeret_12y
NUM_TRIALS=3
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_excel('Data/all_time.xlsx', index_col=0)
#       2 X,y=df.drop(['constrution_year', 'Area', 'floor_level', 'powerplant',
#       3        'road', 'motorway', 'forest', 'coastline', 'airport', 'farmland',
#       4        'industrial', 'carpet', 'cookerhood', 'passive', 'gastove', 'fireplace',
#    (...)      8        'any_1y', 'lrti_3yr', 'urti_3yr', 'rti_3yr', 'fever_3yr', 'gi_3yr',
#       9        'any_3yr'],axis=1),df.verificeret_12y
#      10 NUM_TRIALS=3
#
# File /data/michaelf/miniconda3/envs/gaussion_process/lib/python3.11/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File /data/michaelf/miniconda3/envs/gaussion_process/lib/python3.11/site-packages/pandas/io/excel/_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File /data/michaelf/miniconda3/envs/gaussion_process/lib/python3.11/site-packages/pandas/io/excel/_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File /data/michaelf/miniconda3/envs/gaussion_process/lib/python3.11/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/all_time.xlsx'

# %%
list_parameters=["Indoor Acetald","Indoor Acetone","Indoor formaldehyd","Indoor $PM_{2.5}$","Indoor $NO_x$","Indoor black Carbon","Indoor $NO_2$","LRTI","Gestational age","Street $NO_2$","Street $NO_x$","Street $PM_{2.5}$","Regional $NO_2$","Regional $NO_x$","Regional $PM_{2.5}$","Polygentic risk Score"]

# %%
replace_dict=dict(zip(X.columns,list_parameters))
X=X.rename(columns=replace_dict)

# %%
X.columns

# %%
param_distributions = {
    'n_estimators': randint(100, 400),
    'max_depth': randint(2, 6),"min_impurity_decrease":uniform(0, 0.1),"min_samples_leaf":randint(20, 50)
,"class_weight":['balanced'],"max_features":[0.4,0.5,0.6],"max_samples":[0.4,0.5,0.6],"criterion":[ 'gini']}
performence,shap_values,feature_importance,parameter=nested_cross_validation_classification(X,y,2,3,param_distributions)

# %%
shap_y12=dict(zip(X.columns,X.columns+"_12y"))
shapy12=pd.DataFrame(shap_values[:,:,1],columns=shap_y12)
shapy12.to_excel("shap12.xlsx")

# %%
performence.AUROC_train.mean(),performence.AUROC_train.std(),performence.AUROC_test.mean(),performence.AUROC_test.std()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 performence.AUROC_train.mean(),performence.AUROC_train.std(),performence.AUROC_test.mean(),performence.AUROC_test.std()
#
# NameError: name 'performence' is not defined

# %%
performence.F1_train.mean(),performence.F1_train.std(),performence.F1_test.mean(),performence.F1_test.std()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 performence.F1_train.mean(),performence.F1_train.std(),performence.F1_test.mean(),performence.F1_test.std()
#
# NameError: name 'performence' is not defined

# %%
performence.to_excel("Models/performence_rf_12.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 performence.to_excel("Models/performence_rf_12.xlsx")
#
# NameError: name 'performence' is not defined

# %%
import matplotlib.pyplot as plt

# %%
fig=shap.plots.violin(shap_values[:,:,1],X ,plot_type="layered_violin",show=False)
plt.savefig('shap.png',dpi=300,bbox_inches='tight')
# Out:
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #1 for feature lrti_1y, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #4 for feature lrti_1y, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #5 for feature lrti_1y, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #6 for feature lrti_1y, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #7 for feature lrti_1y, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #8 for feature lrti_1y, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #10 for feature lrti_1y, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
