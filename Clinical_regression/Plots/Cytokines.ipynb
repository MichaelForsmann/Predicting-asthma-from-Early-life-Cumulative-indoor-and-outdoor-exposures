# %%
from Scripts.Random_forest_nested import *
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cyto=pd.read_excel("Data/cyto_prediction.xlsx")

# %%
cyto=cyto.drop(columns=["Unnamed: 0",'lrti_1y.1'],axis=1)

# %%
cytokines=["crp_6mo","il_1β_6mo","il_8_6mo","il_6_6mo","tnf_α_6mo"]

# %%
corr_mat=cyto.corr(method="spearman").drop(cytokines,axis=0).loc[:,cytokines]

# %%
from scipy.stats import  spearmanr

# %%
corr,p=calculate_pvalues(cyto)

# %%
def calculate_pvalues(df):
    df = df._get_numeric_data()
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose()
    pvalues.index=df.columns
    corr = dfcols.transpose()
    corr.index=df.columns
    for r in df.columns:
        for c in df.columns:
            if c == r:
                pvalues.loc[r,c]=1
            else:
                df_corr = df.loc[:,[r,c]].dropna()
                pvalues.loc[r,c] = spearmanr(df_corr.loc[:,r], df_corr.loc[:,c])[1]
                corr.loc[r,c] = spearmanr(df_corr.loc[:,r], df_corr.loc[:,c])[0]
    return df.corr(method="spearman"),pvalues

# %%
mask=p<0.05

# %%
p_shape=p.drop(cytokines,axis=0).loc[:,cytokines]

# %%
soft_max=mask.drop(cytokines,axis=0).loc[:,cytokines]

# %%
corr_shape=corr.drop(cytokines,axis=0).loc[:,cytokines]

# %%
columns=["CPR","$IL \ 1 \u03B2 $","IL 8","IL 6" ,"$TNF \ \u03B1 $" ]

# %%
index1=["Indoor $PM_{2.5}$","Indoor Formalhyde","Street $NO_2$","Street $PM_{2,5}$","Street $NO_x$" ,"Indoor $NO_x$","Indoor Acetald"," Indoor Actone","Indoor Black Carbon","Urban $NO_x$","Urban $NO_x$","Urban $PM_{2,5}$","Indoor Humidity","Fel d1","Der f1"]

# %%
index2=["Der p1","Can f1","Indoor temperature","Cotinine hair","Genetics","Gestational age",'Constrution year','Area',
       'Floor level',"Airport" ,"Forest","Moterway","Road","Farmland"]

# %%
dict1=dict(zip(corr_shape.columns,columns))
corr_shape=corr_shape.rename(columns=dict1).drop(["vocs_season_m6","coastline_m6","powerplant_m6"],axis=0)
dict1_index=dict(zip(corr_shape.index,index1+index2))

# %%
dict1_index
# Out:
# {'pm25_season_m6': 'Indoor $PM_{2.5}$',
#  'form_season_m6': 'Indoor Formalhyde',
#  'no2_str_m6': 'Street $NO_2$',
#  'pm25_str_m6': 'Street $PM_{2,5}$',
#  'nox_str_m6': 'Street $NO_x$',
#  'nox_season_m6': 'Indoor $NO_x$',
#  'acetald_season_m6': 'Indoor Acetald',
#  'acetone_season_m6': ' Indoor Actone',
#  'bc_season_m6': 'Indoor Black Carbon',
#  'nox_urb_m6': 'Urban $NO_x$',
#  'no2_urb_m6': 'Urban $NO_x$',
#  'pm25_urb_m18': 'Urban $PM_{2,5}$',
#  'humidity': 'Indoor Humidity',
#  'fel_d_1_dust': 'Fel d1',
#  'der_f_1_dust': 'Der f1',
#  'der_p_1_dust': 'Der p1',
#  'can_f_1_dust': 'Can f1',
#  'temperature_bedroom': 'Indoor temperature',
#  'cotinine_plasma': 'Cotinine hair',
#  'lrti_1y': 'Genetics',
#  'urti_1y': 'Gestational age',
#  'rti_1y': 'Constrution year',
#  'fever_1y': 'Area',
#  'gi_1y': 'Floor level',
#  'genetic_risk_score_asthma': 'Airport',
#  'gestational_age': 'Forest',
#  'neonatal_fef_05': 'Moterway',
#  'constrution_year_m6': 'Road',
#  'Area_m6': 'Farmland'}

# %%
corr_shape=corr_shape.rename(dict1_index)

# %%
fig,ax=plt.subplots(1,1,figsize=(5,10))
g=sns.heatmap(corr_shape, fmt='g',ax=ax)
for i in range(corr_shape.shape[0]):
    for j in range(corr_shape.shape[1]):
        if p_shape.iloc[i, j]<0.05:
            corr = '{:.2f}'.format(corr_shape.iloc[i, j].round(2)),
            pval = p_shape.iloc[i, j].round(1)
            if p_shape.iloc[i, j]*p_shape.shape[0]<0.05:
                ax.text(j+0.5, i+0.3, corr[0], ha='center', va='center', fontsize=10, color='green')
                ax.text(j+0.5, i+0.7, "**", ha='center', va='center', fontsize=10, color='green')
            else:
                ax.text(j+0.5, i+0.3, corr[0], ha='center', va='center', fontsize=10, color='green')
                ax.text(j+0.5, i+0.7, "*", ha='center', va='center', fontsize=10, color='green')
            
fig.savefig("Plots/cytokine_responds_exposures.png",bbox_inches="tight")

# %%
fig,ax=plt.subplots(1,1,figsize=(5,10))
g=sns.heatmap(corr_shape, fmt='g',ax=ax)
for i in range(corr_shape.shape[0]):
    for j in range(corr_shape.shape[1]):
        if p_shape.iloc[i, j]<0.05:
            corr = '{:.2f}'.format(corr_shape.iloc[i, j].round(2)),
            pval = p_shape.iloc[i, j].round(1)
            if p_shape.iloc[i, j]*p_shape.shape[0]<0.05:
                ax.text(j+0.5, i+0.3, corr[0], ha='center', va='center', fontsize=10, color='green')
                ax.text(j+0.5, i+0.7, "**", ha='center', va='center', fontsize=10, color='green')
            else:
                ax.text(j+0.5, i+0.3, corr[0], ha='center', va='center', fontsize=10, color='green')
                ax.text(j+0.5, i+0.7, "*", ha='center', va='center', fontsize=10, color='green')
            
fig.savefig("Plots/cytokine_responds_exposures.png",bbox_inches="tight")

# %%
for i in range(corr_mat.shape[0]):
    for j, jx in enumerate(g.dendrogram_col.reordered_ind):
        text = g.ax_heatmap.text(j + 0.5,i + 0.3,"*" if df_raw.iloc[i, jx] else "",ha="center",va="center",color="black",size=20)
        text = g.ax_heatmap.text(
                j + 0.5,
                i + 0.6,
                corr_raw.iloc[i, jx].round(2) ,
                ha="center",
                va="center",
                color="white",size=12
            )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 2
#       1 for i in range(corr_mat.shape[0]):
# ----> 2     for j, jx in enumerate(g.dendrogram_col.reordered_ind):
#       3         text = g.ax_heatmap.text(j + 0.5,i + 0.3,"*" if df_raw.iloc[i, jx] else "",ha="center",va="center",color="black",size=20)
#       4         text = g.ax_heatmap.text(
#       5                 j + 0.5,
#       6                 i + 0.6,
#    (...)
#      10                 color="white",size=12
#      11             )
#
# AttributeError: 'Axes' object has no attribute 'dendrogram_col'

# %%
sns.heatmap(corr_mat,annot=soft_max,figsize=(10,10))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 sns.heatmap(corr_mat,annot=soft_max,figsize=(10,10))
#
# File /data/michaelf/miniconda3/lib/python3.10/site-packages/seaborn/matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File /data/michaelf/miniconda3/lib/python3.10/site-packages/seaborn/matrix.py:306, in _HeatMapper.plot(self, ax, cax, kws)
#     303     kws.setdefault("vmax", self.vmax)
#     305 # Draw the heatmap
# --> 306 mesh = ax.pcolormesh(self.plot_data, cmap=self.cmap, **kws)
#     308 # Set the axis limits
#     309 ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
#
# File /data/michaelf/miniconda3/lib/python3.10/site-packages/matplotlib/__init__.py:1476, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1473 @functools.wraps(func)
#    1474 def inner(ax, *args, data=None, **kwargs):
#    1475     if data is None:
# -> 1476         return func(
#    1477             ax,
#    1478             *map(sanitize_sequence, args),
#    1479             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1481     bound = new_sig.bind(ax, *args, **kwargs)
#    1482     auto_label = (bound.arguments.get(label_namer)
#    1483                   or bound.kwargs.get(label_namer))
#
# File /data/michaelf/miniconda3/lib/python3.10/site-packages/matplotlib/axes/_axes.py:6434, in Axes.pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6430 coords = np.stack([X, Y], axis=-1)
#    6432 kwargs.setdefault('snap', mpl.rcParams['pcolormesh.snap'])
# -> 6434 collection = mcoll.QuadMesh(
#    6435     coords, antialiased=antialiased, shading=shading,
#    6436     array=C, cmap=cmap, norm=norm, alpha=alpha, **kwargs)
#    6437 collection._scale_norm(norm, vmin, vmax)
#    6439 coords = coords.reshape(-1, 2)  # flatten the grid structure; keep x, y
#
# File /data/michaelf/miniconda3/lib/python3.10/site-packages/matplotlib/collections.py:2146, in QuadMesh.__init__(self, coordinates, antialiased, shading, **kwargs)
#    2144 kwargs.setdefault("pickradius", 0)
#    2145 super().__init__(coordinates=coordinates, shading=shading)
# -> 2146 Collection.__init__(self, **kwargs)
#    2148 self._antialiased = antialiased
#    2149 self._bbox = transforms.Bbox.unit()
#
# File /data/michaelf/miniconda3/lib/python3.10/site-packages/matplotlib/collections.py:206, in Collection.__init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, offset_transform, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     203 self._offset_transform = offset_transform
#     205 self._path_effects = None
# --> 206 self._internal_update(kwargs)
#     207 self._paths = None
#
# File /data/michaelf/miniconda3/lib/python3.10/site-packages/matplotlib/artist.py:1216, in Artist._internal_update(self, kwargs)
#    1209 def _internal_update(self, kwargs):
#    1210     """
#    1211     Update artist properties without prenormalizing them, but generating
#    1212     errors as if calling `set`.
#    1213
#    1214     The lack of prenormalization is to maintain backcompatibility.
#    1215     """
# -> 1216     return self._update_props(
#    1217         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1218         "{prop_name!r}")
#
# File /data/michaelf/miniconda3/lib/python3.10/site-packages/matplotlib/artist.py:1190, in Artist._update_props(self, props, errfmt)
#    1188             func = getattr(self, f"set_{k}", None)
#    1189             if not callable(func):
# -> 1190                 raise AttributeError(
#    1191                     errfmt.format(cls=type(self), prop_name=k))
#    1192             ret.append(func(v))
#    1193 if ret:
#
# AttributeError: QuadMesh.set() got an unexpected keyword argument 'figsize'

# %%
param_distributions = {
    'n_estimators': randint(100, 400),
    'max_depth': randint(2, 10),"min_impurity_decrease":uniform(0.001, 0.03),"min_samples_leaf":[10,15]
,"max_features":[0.9,0.95],"max_samples":[0.9,0.95]}

# %%
performence,shap_values,feature_importance,parameter=nested_cross_validation_Regression(X,y,2,3,param_distributions)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# done % 0.16666666666666666
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# done % 0.3333333333333333
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# done % 0.5
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# done % 0.6666666666666666
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# done % 0.8333333333333334
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# done % 1.0

# %%
parameter
# Out:
# [{'max_depth': 6,
#   'max_features': 0.9,
#   'max_samples': 0.95,
#   'min_impurity_decrease': 0.005679835610086079,
#   'min_samples_leaf': 10,
#   'n_estimators': 187},
#  {'max_depth': 6,
#   'max_features': 0.9,
#   'max_samples': 0.9,
#   'min_impurity_decrease': 0.0013979488347959958,
#   'min_samples_leaf': 10,
#   'n_estimators': 113},
#  {'max_depth': 5,
#   'max_features': 0.9,
#   'max_samples': 0.95,
#   'min_impurity_decrease': 0.018772437065861274,
#   'min_samples_leaf': 10,
#   'n_estimators': 234},
#  {'max_depth': 9,
#   'max_features': 0.95,
#   'max_samples': 0.95,
#   'min_impurity_decrease': 0.007370173320348284,
#   'min_samples_leaf': 15,
#   'n_estimators': 376},
#  {'max_depth': 3,
#   'max_features': 0.95,
#   'max_samples': 0.9,
#   'min_impurity_decrease': 0.0014789875666064258,
#   'min_samples_leaf': 15,
#   'n_estimators': 191},
#  {'max_depth': 9,
#   'max_features': 0.95,
#   'max_samples': 0.95,
#   'min_impurity_decrease': 0.007370173320348284,
#   'min_samples_leaf': 15,
#   'n_estimators': 376}]

# %%
performence
# Out:
#    R_squared_train  R_squared_test  root_mean_squared_error_train  \
# 0         0.401375       -0.079494                       0.489304
# 1         0.379561       -0.057457                       0.465769
# 2         0.269577       -0.050861                       0.517891
# 3         0.287655       -0.024250                       0.521283
# 4         0.272825       -0.109228                       0.524742
# 5         0.323397       -0.021257                       0.490961
#
#    root_mean_squared_error_test
# 0                      0.582479
# 1                      0.661915
# 2                      0.635103
# 3                      0.597077
# 4                      0.631946
# 5                      0.641288

# %%
feature_importance
# Out:
# acetald_season_m6            0.059465
# acetone_season_m6            0.053249
# bc_season_m6                 0.026818
# can_f_1_dust                 0.035809
# cotinine_plasma              0.033041
# der_f_1_dust                 0.048733
# der_p_1_dust                 0.034555
# fel_d_1_dust                 0.037820
# form_season_m6               0.037299
# genetic_risk_score_asthma    0.051824
# gestational_age              0.024476
# humidity                     0.096997
# lrti_1y                      0.005530
# no2_str_m6                   0.037477
# nox_season_m6                0.040059
# nox_str_m6                   0.072482
# pm25_season_m6               0.024014
# pm25_str_m6                  0.077508
# temperature_bedroom          0.057329
# vocs_season_m6               0.145516
# dtype: float64

# %%
fig=shap.plots.violin(shap_values[:,:],X ,plot_type="layered_violin")
# Out:
# /data/michaelf/miniconda3/lib/python3.10/site-packages/shap/plots/_violin.py:304: UserWarning: Not enough data in bin #5 for feature lrti_1y, so it'll be ignored. Try increasing the number of records to plot.
#   warnings.warn(
