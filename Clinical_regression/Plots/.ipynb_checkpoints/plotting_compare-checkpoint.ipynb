# %%
from Make_logistic import *
import numpy as np
import matplotlib.pyplot as  plt

# %%
asthma_7_exposure = az.from_netcdf("asthma_7y.nc")
asthma_12_exposure = az.from_netcdf("asthma_12y.nc")
asthma_18_exposure = az.from_netcdf("asthma_18y.nc")

# %%
list_parameters=["Indoor Acetald","Indoor Acetone","Indoor formaldehyd","Indoor $PM_{2.5}$","Indoor $NO_x$","Indoor black Carbon","Indoor $NO_2$","Lower respiratory tract infection","Genetics","Gestational age","Outdoor $NO_2$","Outdoor $NO_x$","Outdoor $PM_{2.5}$"]

coords={"weight_dim_1": list_parameters}

# %%
list_parameters
# Out:
# ['Indoor Acetald',
#  'Indoor Acetone',
#  'Indoor formaldehyd',
#  'Indoor $PM_{2.5}$',
#  'Indoor $NO_x$',
#  'Indoor black Carbon',
#  'Indoor $NO_2$',
#  'Lower respiratory tract infection',
#  'Genetics',
#  'Gestational age',
#  'Outdoor $NO_2$',
#  'Outdoor $NO_x$',
#  'Outdoor $PM_{2.5}$']

# %%
ax = az.plot_forest(
    [asthma_7_exposure,asthma_12_exposure,asthma_18_exposure], hdi_prob=0.01,quartiles=True,model_names = ["Asthma_7_year", "Asthma_12_year","Asthma_18_year"],combined=True,ridgeplot_quantiles=[0.05,0.95], var_names="weight",rope=[0.99,1.01])

ax[0].set_title('Odds ratio pr standard deviation',fontsize=15)
fig = plt.gcf() 

# 3. Save the figure to a file
# Use .png, .pdf, .svg, etc. as the extension
fig.savefig("multiple_coerf.png",dpi=300,bbox_inches='tight')

# Optional: Close the plot to prevent it from displaying in some environments
plt.close(fig)

# %%
fig

# %%
ax = az.plot_forest(
    [asthma_7_exposure,asthma_12_exposure,asthma_18_exposure],model_names = ["Asthma_7_year", "Asthma_12_year","Asthma_18_year"],ridgeplot_quantiles=[0.05,0.95], var_names="weight",rope=[0.99,1.01])

# %%
az.plot_ppc(data, data_pairs={"y":"y"})
# Out:
# Inference data with groups:
# 	> posterior
# 	> posterior_predictive
# 	> sample_stats
# 	> prior
# 	> prior_predictive
# 	> observed_data

# %%
asthma_7_exposure.posterior.mean(dim=["chain"])

# %%
create_predictions(asthma_7_exposure.posterior.mean(dim=["chain"]),asthma_7_exposure.posterior_predictive.obs)

# %%
asthma_7_exposure.posterior["weight"].
# Out:
#   Cell In[38], line 1
#     asthma_7_exposure.posterior["weight"].
#                                           ^
# SyntaxError: invalid syntax
