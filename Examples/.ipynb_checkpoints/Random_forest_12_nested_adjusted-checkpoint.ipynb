# %%
from Scripts.Random_forest_nested_fixed import *

# %%
df = pd.read_excel('Data/all_time.xlsx', index_col=0)
X,y=df.drop(['constrution_year', 'Area', 'floor_level', 'powerplant',
       'road', 'motorway', 'forest', 'coastline', 'airport', 'farmland',
       'industrial', 'carpet', 'cookerhood', 'passive', 'gastove', 'fireplace',
       'corrected_week','scale_formaldehyd', 'scale_acetald', 'scale_vocs',"scaled_vocs",
      'asthma_0_7yrs', 'verificeret_18y', 'verificeret_12y', 'crp_6mo', 'il_1β_6mo', 'il_8_6mo', 'il_6_6mo',
       'tnf_α_6mo', 'urti_1y', 'rti_1y', 'fever_1y', 'gi_1y',
       'any_1y', 'lrti_3yr', 'urti_3yr', 'rti_3yr', 'fever_3yr', 'gi_3yr',
       'any_3yr'],axis=1),df.verificeret_12y
NUM_TRIALS=2

# %%
list_parameters=["$NO_x$","$NO_2$","Formaldehyd","Acetone","Acetald","Black Carbon","$PM_{2.5}$","Regional $NO_2$","Regional $NO_x$","Regional $PM_{2.5}$","Street $NO_2$","Street $NO_x$","Street $PM_{2.5}$","BMI","Gestational age","Mother Education",'LRTI',"Polygenetic risk score","Landuse 1","Landuse 2"]

# %%
replace_dict=dict(zip(X.columns,list_parameters))
X=X.rename(columns=replace_dict)

# %%
replace_dict
# Out:
# {'scaled_nox': '$NO_x$',
#  'scaled_no2': '$NO_2$',
#  'scaled_formaldehyd': 'Formaldehyd',
#  'scaled_acetone': 'Acetone',
#  'scaled_acetald': 'Acetald',
#  'scaled_bc': 'Black Carbon',
#  'scaled_PM25': '$PM_{2.5}$',
#  'no2_regional': 'Regional $NO_2$',
#  'nox_regional': 'Regional $NO_x$',
#  'pm25_regional': 'Regional $PM_{2.5}$',
#  'no2_street': 'Street $NO_2$',
#  'nox_street': 'Street $NO_x$',
#  'pm25_street': 'Street $PM_{2.5}$',
#  'bmi_6_yrs': 'BMI',
#  'gestational_age': 'Gestational age',
#  "mother's_education_1yr": 'Mother Education',
#  'lrti_1y': 'LRTI',
#  'genetic_risk_score_asthma': 'Polygenetic risk score',
#  'PCA1': 'Landuse 1',
#  'PCA2': 'Landuse 2'}

# %%
param_distributions = {
    'n_estimators': randint(100, 400),
    'max_depth': randint(2, 6),"min_impurity_decrease":uniform(0, 0.1),"min_samples_leaf":randint(20, 50)
,"class_weight":['balanced'],"max_features":[0.4,0.5,0.6],"max_samples":[0.4,0.5,0.6],"criterion":[ 'gini']}
performence,shap_values,feature_importance,parameter=nested_cross_validation_classification(X,y,2,3,param_distributions,n=100)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Done: 16.7%
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Done: 33.3%
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Done: 50.0%
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Done: 66.7%
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Done: 83.3%
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Done: 100.0%

# %%
shap_y12=dict(zip(X.columns,X.columns+"_12y"))
shapy12=pd.DataFrame(shap_values[:,:,1],columns=shap_y12)
shapy12.to_excel("_adjusted_shap12.xlsx")

# %%
performence.AUROC_train.mean(),performence.AUROC_train.std(),performence.AUROC_test.mean(),performence.AUROC_test.std()
# Out:
# (np.float64(0.7863177662088118),
#  np.float64(0.04297796678217547),
#  np.float64(0.6421928746928748),
#  np.float64(0.03420996991682183))

# %%
performence.F1_train.mean(),performence.F1_train.std(),performence.F1_test.mean(),performence.F1_test.std()
# Out:
# (np.float64(0.40664675691171565),
#  np.float64(0.06893090133089212),
#  np.float64(0.22829295460874408),
#  np.float64(0.0838345580221335))

# %%
performence.to_excel("Models/performence_rf_12_adjusted.xlsx")

# %%
import matplotlib.pyplot as plt

# %%
fig=shap.plots.violin(shap_values[:,:,1],X ,plot_type="layered_violin",show=False,max_display=30)
plt.savefig('Plots/shap_12_adjusted.png',dpi=300,bbox_inches='tight')

# %%
shap.plots.beeswarm(shap_values[:,:,1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 shap.plots.beeswarm(shap_values[:,:,1])
#
# File /data/michaelf/miniconda3/envs/gaussion_process/lib/python3.11/site-packages/shap/plots/_beeswarm.py:111, in beeswarm(shap_values, max_display, order, clustering, cluster_threshold, color, axis_color, alpha, ax, show, log_scale, color_bar, s, plot_size, color_bar_label, group_remaining_features)
#     109 if not isinstance(shap_values, Explanation):
#     110     emsg = "The beeswarm plot requires an `Explanation` object as the `shap_values` argument."
# --> 111     raise TypeError(emsg)
#     113 sv_shape = shap_values.shape
#     114 if len(sv_shape) == 1:
#
# TypeError: The beeswarm plot requires an `Explanation` object as the `shap_values` argument.
