# %%
from Scripts.Random_forest_nested import *
import matplotlib.pyplot as plt
import pickle

# %%
df = pd.read_excel('Data/all_time.xlsx', index_col=0)
X,y=df.loc[:,['scaled_nox','scaled_no2','scaled_formaldehyd','scaled_acetone','scaled_acetald',
    'scaled_bc', 'scaled_PM25','no2_street', 'nox_street', 'pm25_street', 'gestational_age', 'lrti_1y',
       'genetic_risk_score_asthma']],df.verificeret_12y

# %%
list_parameters=["$NO_x$","$NO_2$","Formaldehyd","Acetone","Acetald",'constrution_year',"Black Carbon","$PM_{2.5}$","Street $NO_2$","Street $NO_x$","Street $PM_{2.5}$","Gestational age","LRTI","Polygenetic risk score"]

# %%
replace_dict=dict(zip(X.columns,list_parameters))
X=X.rename(columns=replace_dict)

# %%
param_distributions = {
    'n_estimators':           [300],
    'max_depth':              randint(2, 6),
    'min_samples_leaf':       randint(10, 30),
    'max_features':           [0.4, 0.5, 0.6, 'sqrt'],
    'max_samples':            [0.5, 0.6, 0.7, 0.8],
    # class_weight removed
}
dataframe =nested_cross_calibrated_rf(
    X, y,
    Number_CV=2,
    number_split=3,
    n_neighbors_imputer=25,
    param_distributions=param_distributions,
    calibration_method="isotonic")
# Out:
# Fold 1/6  AUC=0.667  BSS=+0.057  ICI=0.017
# Fold 2/6  AUC=0.661  BSS=-0.019  ICI=0.038
# Fold 3/6  AUC=0.642  BSS=+0.012  ICI=0.022
# Fold 4/6  AUC=0.657  BSS=+0.048  ICI=0.033
# Fold 5/6  AUC=0.677  BSS=+0.053  ICI=0.028
# Fold 6/6  AUC=0.674  BSS=-0.077  ICI=0.050

# %%
with open("Data/results_rf_12y.pkl", "wb") as f:
    pickle.dump(dataframe, f)

# %%
shap_y18=dict(zip(X.columns,X.columns+"_12y"))
shapy18=pd.DataFrame(dataframe['shap_values_oof'],columns=shap_y18)
shapy18.to_excel("Data/shap12.xlsx")

# %%
performence.AUROC_train.mean(),performence.AUROC_train.std(),performence.AUROC_test.mean(),performence.AUROC_test.std()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 performence.AUROC_train.mean(),performence.AUROC_train.std(),performence.AUROC_test.mean(),performence.AUROC_test.std()
#
# NameError: name 'performence' is not defined

# %%
performence.to_excel("Models/performence_rf_12.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 performence.to_excel("Models/performence_rf_12.xlsx")
#
# NameError: name 'performence' is not defined

# %%
pd.concat([performence,pd.DataFrame(parameter)],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 pd.concat([performence,pd.DataFrame(parameter)],axis=1)
#
# NameError: name 'performence' is not defined

# %%
calibration[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 calibration[0]
#
# NameError: name 'calibration' is not defined

# %%
import matplotlib.pyplot as plt

# %%
fig=shap.plots.violin(dataframe['shap_values_oof'],X ,plot_type="layered_violin",show=False)
plt.rcParams.update({
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica", "Arial", "DejaVu Sans"],
})
# increase pad to push title further away


plt.savefig('Plots/shap_12.png',dpi=300,bbox_inches='tight')
