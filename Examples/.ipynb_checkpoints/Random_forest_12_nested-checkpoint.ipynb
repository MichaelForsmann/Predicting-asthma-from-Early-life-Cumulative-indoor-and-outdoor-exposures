# %%
from Scripts.Random_forest_nested_fixed import *

# %%
df = pd.read_excel('../Data_and_Preprocessing/Scaled_data_18m.xlsx', index_col=0)

X,y=df.drop(['constrution_year', 'Area', 'floor_level', 'powerplant',
       'road', 'motorway', 'forest', 'coastline', 'airport', 'farmland',
       'industrial', 'carpet', 'cookerhood', 'passive', 'gastove', 'fireplace',
       'corrected_week','scale_formaldehyd', 'scale_acetald', 'scale_vocs',"scaled_vocs",'bmi_6_yrs', 'mother\'s_education_1yr',
       'asthma_0_7yrs', 'verificeret_18y', 'verificeret_12y', 'crp_6mo', 'il_1β_6mo', 'il_8_6mo', 'il_6_6mo',
       'tnf_α_6mo', 'urti_1y', 'rti_1y', 'fever_1y', 'gi_1y',
       'any_1y', 'lrti_3yr', 'urti_3yr', 'rti_3yr', 'fever_3yr', 'gi_3yr',
       'any_3yr'],axis=1),df.verificeret_18y
NUM_TRIALS=2

# %%
X.columns
# Out:
# Index(['scaled_nox', 'scaled_no2', 'scaled_formaldehyd', 'scaled_acetone',
#        'scaled_acetald', 'scaled_bc', 'scaled_PM25', 'no2_regional',
#        'nox_regional', 'pm25_regional', 'no2_street', 'nox_street',
#        'pm25_street', 'gestational_age', 'lrti_1y',
#        'genetic_risk_score_asthma'],
#       dtype='object')

# %%
list_parameters=["$NO_x$","$NO_2$","Formaldehyd","Acetone","Acetald","Black Carbon","$PM_{2.5}$","Regional $NO_2$","Regional $NO_x$","Regional $PM_{2.5}$","Street $NO_2$","Street $NO_x$","Street $PM_{2.5}$","Gestational age","LRTI","Polygenetic risk score"]

# %%
replace_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 replace_dict
#
# NameError: name 'replace_dict' is not defined

# %%
replace_dict=dict(zip(X.columns,list_parameters))
X=X.rename(columns=replace_dict)

# %%
param_distributions = {
    'n_estimators': randint(100, 400),
    'max_depth': randint(2, 6),"min_impurity_decrease":uniform(0, 0.1),"min_samples_leaf":randint(20, 50)
,"class_weight":['balanced'],"max_features":[0.4,0.5,0.6],"max_samples":[0.4,0.5,0.6],"criterion":[ 'gini']}
performence,shap_values,feature_importance,parameter=nested_cross_validation_classification(X,y,2,3,param_distributions,n=100)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Done: 16.7%
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Done: 33.3%
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Done: 50.0%
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Done: 66.7%
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Done: 83.3%
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Done: 100.0%

# %%
shap_values.shape
# Out:
# (389, 16, 2)

# %%
feature_importance
# Out:
# $NO_x$                    0.054155
# $NO_2$                    0.042837
# Formaldehyd               0.123414
# Acetone                   0.039117
# Acetald                   0.040159
# Black Carbon              0.054058
# $PM_{2.5}$                0.049725
# Regional $NO_2$           0.120470
# Regional $NO_x$           0.110718
# Regional $PM_{2.5}$       0.092341
# Street $NO_2$             0.069194
# Street $NO_x$             0.025940
# Street $PM_{2.5}$         0.053487
# Gestational age           0.056755
# LRTI                      0.002272
# Polygenetic risk score    0.065358
# dtype: float64

# %%
shap_y18=dict(zip(X.columns,X.columns+"_18y"))
shapy18=pd.DataFrame(shap_values[:,:,1],columns=shap_y18)
shapy18.to_excel("shap18.xlsx")

# %%
performence.AUROC_train.mean(),performence.AUROC_train.std(),performence.AUROC_test.mean(),performence.AUROC_test.std()
# Out:
# (np.float64(0.7293131281407036),
#  np.float64(0.06986282744450723),
#  np.float64(0.5346346801346802),
#  np.float64(0.047925569153287856))

# %%
performence.to_excel("Models/performence_rf_18.xlsx")

# %%
pd.concat([performence,pd.DataFrame(parameter)],axis=1)
# Out:
#    AUROC_train  AUROC_test  F1_train   F1_test class_weight criterion  \
# 0     0.779732    0.519333  0.477612  0.324324     balanced      gini
# 1     0.703518    0.479667  0.444444  0.337079     balanced      gini
# 2     0.715250    0.598316  0.460317  0.245614     balanced      gini
# 3     0.705821    0.486333  0.444444  0.305882     balanced      gini
# 4     0.836683    0.575000  0.521008  0.269231     balanced      gini
# 5     0.634875    0.549158  0.442623  0.298507     balanced      gini
#
#    max_depth  max_features  max_samples  min_impurity_decrease  \
# 0          5           0.4          0.6               0.003143
# 1          5           0.6          0.5               0.056187
# 2          3           0.4          0.4               0.011987
# 3          5           0.6          0.4               0.004360
# 4          4           0.5          0.6               0.005587
# 5          3           0.5          0.5               0.092666
#
#    min_samples_leaf  n_estimators
# 0                26           340
# 1                31           282
# 2                31           251
# 3                31           319
# 4                22           314
# 5                35           370

# %%
performence.F1_train.mean(),performence.F1_train.std(),performence.F1_test.mean(),performence.F1_test.std()
# Out:
# (np.float64(0.4650749406143122),
#  np.float64(0.03054075580236542),
#  np.float64(0.2967729326593249),
#  np.float64(0.03419188169212302))

# %%
import matplotlib.pyplot as plt

# %%
fig=shap.plots.violin(shap_values[:,:,1],X ,plot_type="layered_violin",show=False)
plt.rcParams.update({
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica", "Arial", "DejaVu Sans"],
})
# increase pad to push title further away


plt.savefig('Plots/shap_18.png',dpi=300,bbox_inches='tight')
