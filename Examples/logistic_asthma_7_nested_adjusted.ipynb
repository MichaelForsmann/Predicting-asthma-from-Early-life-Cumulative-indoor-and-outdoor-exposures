# %% [markdown]
# #

# %%
from Scripts.make_logistic_numpyro import *
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
import arviz as az
import pickle

# %%
df = pd.read_excel('../SImulated_data/Clinical_synthetic.xlsx', index_col=0)
X,y=df.loc[:,['scaled_nox', 'scaled_no2', 'scaled_formaldehyd', 'scaled_acetone',
       'scaled_acetald', 'scaled_bc', 'scaled_PM25', 'no2_street', 'nox_street',
       'pm25_street', 'bmi_6_yrs', 'gestational_age', 'mother\'s_education_1yr',
        'genetic_risk_score_asthma', 'PCA1', 'PCA2']],df.asthma_0_7yrs

# %%
df.corr().scaled_nox.no2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.corr().scaled_nox.no2
#
# File /data/michaelf/miniconda3/envs/clinical_regression/lib/python3.14/site-packages/pandas/core/generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'no2'

# %%
Dataframe=nested_cross_bayesian_logistic(X,y,2,3,"../Models/asthma_7_year_adjusted")
# Out:
# /home/michaelf/Predicting-asthma-from-early-life-cumulative-indoor-and-outdoor-exposures_github/Traning/Scripts/make_logistic_numpyro.py:58: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /data/michaelf/miniconda3/envs/clinical_regression/lib/python3.14/site-packages/arviz_base/base.py:131: UserWarning: Found chain dimension to be longer than draw dimension, check dimensions are correctly named.
#   warnings.warn(
# /home/michaelf/Predicting-asthma-from-early-life-cumulative-indoor-and-outdoor-exposures_github/Traning/Scripts/make_logistic_numpyro.py:58: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /data/michaelf/miniconda3/envs/clinical_regression/lib/python3.14/site-packages/arviz_base/base.py:131: UserWarning: Found chain dimension to be longer than draw dimension, check dimensions are correctly named.
#   warnings.warn(
# /home/michaelf/Predicting-asthma-from-early-life-cumulative-indoor-and-outdoor-exposures_github/Traning/Scripts/make_logistic_numpyro.py:58: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /data/michaelf/miniconda3/envs/clinical_regression/lib/python3.14/site-packages/arviz_base/base.py:131: UserWarning: Found chain dimension to be longer than draw dimension, check dimensions are correctly named.
#   warnings.warn(
# /home/michaelf/Predicting-asthma-from-early-life-cumulative-indoor-and-outdoor-exposures_github/Traning/Scripts/make_logistic_numpyro.py:58: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /data/michaelf/miniconda3/envs/clinical_regression/lib/python3.14/site-packages/arviz_base/base.py:131: UserWarning: Found chain dimension to be longer than draw dimension, check dimensions are correctly named.
#   warnings.warn(
# /home/michaelf/Predicting-asthma-from-early-life-cumulative-indoor-and-outdoor-exposures_github/Traning/Scripts/make_logistic_numpyro.py:58: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /data/michaelf/miniconda3/envs/clinical_regression/lib/python3.14/site-packages/arviz_base/base.py:131: UserWarning: Found chain dimension to be longer than draw dimension, check dimensions are correctly named.
#   warnings.warn(
# /home/michaelf/Predicting-asthma-from-early-life-cumulative-indoor-and-outdoor-exposures_github/Traning/Scripts/make_logistic_numpyro.py:58: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /data/michaelf/miniconda3/envs/clinical_regression/lib/python3.14/site-packages/arviz_base/base.py:131: UserWarning: Found chain dimension to be longer than draw dimension, check dimensions are correctly named.
#   warnings.warn(

# %%
with open("../Performence/results_adjusted_7y.pkl", "wb") as f:
    pickle.dump(Dataframe, f)

# %%
Dataframe
# Out:
# {'performance_train': {'roc_train': array([[0.52103081, 0.51885861, 0.49121248, ..., 0.59221959, 0.52369668,
#           0.44934834],
#          [0.6724921 , 0.65649684, 0.58550553, ..., 0.71662717, 0.6896722 ,
#           0.671406  ],
#          [0.52840016, 0.61055425, 0.59365173, ..., 0.64052673, 0.66411164,
#           0.44909591],
#          [0.69016588, 0.6782188 , 0.66340837, ..., 0.66716035, 0.58975118,
#           0.67219589],
#          [0.48667062, 0.60979463, 0.58738152, ..., 0.5068128 , 0.52241311,
#           0.59468799],
#          [0.52279874, 0.51061321, 0.56122248, ..., 0.6023978 , 0.61861242,
#           0.54864387]], shape=(6, 500)),
#   'brier_train': array([[0.15210947, 0.15242307, 0.15203853, ..., 0.14987835, 0.1521322 ,
#           0.15344974],
#          [0.14369284, 0.14724104, 0.15010409, ..., 0.14443418, 0.14547645,
#           0.14506666],
#          [0.15109624, 0.14782947, 0.14887637, ..., 0.14774974, 0.14560013,
#           0.15184543],
#          [0.14717793, 0.14312609, 0.14415005, ..., 0.14394096, 0.14848743,
#           0.14409044],
#          [0.1515325 , 0.14754234, 0.14912255, ..., 0.15109436, 0.15366532,
#           0.14973477],
#          [0.15150507, 0.153759  , 0.15196003, ..., 0.15076719, 0.14975354,
#           0.151115  ]], shape=(6, 500)),
#   'ici_train': array([[0.02245594, 0.04535171, 0.03573396, ..., 0.04064222, 0.03341156,
#           0.04414364],
#          [0.0291364 , 0.0400565 , 0.03248119, ..., 0.04008093, 0.04012069,
#           0.05371997],
#          [0.02519733, 0.02647168, 0.02433257, ..., 0.04970143, 0.03196917,
#           0.04589026],
#          [0.04477227, 0.02033831, 0.0145464 , ..., 0.02232276, 0.03872992,
#           0.01134714],
#          [0.01867558, 0.01708474, 0.02574677, ..., 0.03156189, 0.05373648,
#           0.02619475],
#          [0.03360638, 0.0585772 , 0.0367303 , ..., 0.02795195, 0.02994282,
#           0.04639629]], shape=(6, 500)),
#   'bss_train': array([[-0.00847168, -0.01055079, -0.00800133, ...,  0.00632044,
#           -0.00862234, -0.01735755],
#          [ 0.04732984,  0.02380557,  0.00482382, ...,  0.04241478,
#            0.03550468,  0.03822149],
#          [-0.00175403,  0.01990432,  0.0129635 , ...,  0.02043297,
#            0.03468469, -0.00672107],
#          [ 0.02422396,  0.05108735,  0.04429857, ...,  0.04568484,
#            0.01554211,  0.04469374],
#          [-0.00464641,  0.02180797,  0.01133134, ..., -0.00174159,
#           -0.01878679,  0.00727241],
#          [-0.00446453, -0.01940791, -0.00748089, ...,  0.00042752,
#            0.00714793, -0.00187842]], shape=(6, 500))},
#  'performance_test': {'roc_test': array([[0.60927673, 0.54599057, 0.45597484, ..., 0.62814465, 0.51454403,
#           0.55896226],
#          [0.38246855, 0.48073899, 0.33490566, ..., 0.52122642, 0.49960692,
#           0.44339623],
#          [0.51587302, 0.4484127 , 0.46587302, ..., 0.37063492, 0.44047619,
#           0.40873016],
#          [0.53930818, 0.43867925, 0.56132075, ..., 0.48545597, 0.48191824,
#           0.52672956],
#          [0.47327044, 0.51650943, 0.50550314, ..., 0.45794025, 0.49371069,
#           0.50746855],
#          [0.40714286, 0.56626984, 0.48492063, ..., 0.66785714, 0.425     ,
#           0.49761905]], shape=(6, 500)),
#   'brier_test': array([[0.14928102, 0.15140311, 0.15197302, ..., 0.14902963, 0.1517192 ,
#           0.15130357],
#          [0.1723225 , 0.16710322, 0.15591279, ..., 0.1738534 , 0.15996325,
#           0.15904796],
#          [0.15177314, 0.15586889, 0.15371668, ..., 0.16380602, 0.16387528,
#           0.15317631],
#          [0.17755091, 0.16159606, 0.15535787, ..., 0.15742029, 0.16204219,
#           0.16645551],
#          [0.15109044, 0.15702747, 0.15421365, ..., 0.15081905, 0.15408559,
#           0.15111925],
#          [0.15365396, 0.15388857, 0.15430526, ..., 0.14469659, 0.16032217,
#           0.15406963]], shape=(6, 500)),
#   'ici_test': array([[0.04307815, 0.02794525, 0.04210486, ..., 0.04552061, 0.04682296,
#           0.05258725],
#          [0.13632139, 0.09026997, 0.09311598, ..., 0.12305889, 0.0858327 ,
#           0.08221925],
#          [0.02777688, 0.05789139, 0.03853169, ..., 0.11337646, 0.10627441,
#           0.05348163],
#          [0.09481792, 0.09393428, 0.05297009, ..., 0.06917489, 0.06626374,
#           0.07699922],
#          [0.04883928, 0.07238114, 0.06300237, ..., 0.02653975, 0.05681904,
#           0.04792322],
#          [0.05128815, 0.05952444, 0.04496462, ..., 0.03670019, 0.08365118,
#           0.05910103]], shape=(6, 500)),
#   'bss_test': array([[ 1.02806706e-02, -3.78858411e-03, -7.56703322e-03, ...,
#            1.19474126e-02, -5.88418790e-03, -3.12864477e-03],
#          [-1.42482147e-01, -1.07878801e-01, -3.36872941e-02, ...,
#           -1.52631876e-01, -6.05414904e-02, -5.44732099e-02],
#          [-6.24181970e-03, -3.33962490e-02, -1.91273329e-02, ...,
#           -8.60187056e-02, -8.64778969e-02, -1.55446922e-02],
#          [-1.77146054e-01, -7.13668667e-02, -3.00082310e-02, ...,
#           -4.36819173e-02, -7.43246397e-02, -1.03584552e-01],
#          [-1.71560399e-03, -4.10775280e-02, -2.24221888e-02, ...,
#            8.37186467e-05, -2.15731590e-02, -1.90657147e-03],
#          [-1.87115119e-02, -2.02669138e-02, -2.30295701e-02, ...,
#            4.06750266e-02, -6.29211250e-02, -2.14673514e-02]],
#         shape=(6, 500))},
#  'summary': {'prevalence': 0.18508997429305912,
#   'baseline_brier': 0.15083167570925382,
#   'pooled_oof_roc_train': array([0.68009479, 0.74693918, 0.70165094, 0.72136651, 0.67377567,
#          0.69526336]),
#   'pooled_oof_brier_train': array([0.14746645, 0.14135012, 0.1463079 , 0.14272273, 0.1487041 ,
#          0.14788513]),
#   'pooled_oof_bss_train': array([0.02231113, 0.06286183, 0.02999221, 0.05376158, 0.01410565,
#          0.01953533]),
#   'pooled_oof_roc_test': array([0.54166667, 0.44889937, 0.4202381 , 0.52437107, 0.61281447,
#          0.54126984]),
#   'pooled_oof_brier_test': array([0.15044332, 0.15665609, 0.15428448, 0.15373638, 0.14932662,
#          0.15082514]),
#   'pooled_oof_bss_test': array([ 2.57479207e-03, -3.86153022e-02, -2.28917534e-02, -1.92579377e-02,
#           9.97836307e-03,  4.33121810e-05]),
#   'pooled_oof_ici_train': array([0.06267507, 0.06929493, 0.07130951, 0.06935673, 0.06520441,
#          0.07294199]),
#   'pooled_oof_ici_test': array([0.04620382, 0.06431593, 0.06273697, 0.06052525, 0.03780355,
#          0.01795146]),
#   'mean_per_fold_roc': 0.4992841244883698,
#   'mean_per_fold_brier': 0.15600178429484368,
#   'mean_per_fold_ici': 0.061551093074892434,
#   'mean_per_fold_bss': -0.034277339698564765,
#   'total_divergences': 0},
#  'model': <function Scripts.make_logistic_numpyro.logistic_regression_model(features, target=None)>,
#  'mcmc_last_fold': <numpyro.infer.mcmc.MCMC at 0x7410486917f0>,
#  'calibration_train': [(array([0.07692308, 0.11538462, 0.07692308, 0.15384615, 0.11538462,
#           0.12      , 0.19230769, 0.38461538, 0.19230769, 0.42307692]),
#    array([0.15617355, 0.16703621, 0.17347423, 0.17916205, 0.18466299,
#           0.18907944, 0.19387733, 0.20187476, 0.21053445, 0.22466833])),
#   (array([0.        , 0.        , 0.11538462, 0.07692308, 0.15384615,
#           0.2       , 0.23076923, 0.30769231, 0.42307692, 0.34615385]),
#    array([0.10921668, 0.13222731, 0.14651236, 0.15768881, 0.17145927,
#           0.18758401, 0.20359638, 0.22447961, 0.25005524, 0.29673147])),
#   (array([0.03846154, 0.07692308, 0.07692308, 0.11538462, 0.19230769,
#           0.15384615, 0.15384615, 0.30769231, 0.46153846, 0.26923077]),
#    array([0.14640025, 0.16082496, 0.16993826, 0.17708264, 0.18222721,
#           0.18856683, 0.19505132, 0.20187824, 0.21523108, 0.23589185])),
#   (array([0.07692308, 0.03846154, 0.15384615, 0.07692308, 0.03846154,
